# %%
path_hanoi = '/content/drive/MyDrive/HUST/20202/Tích hợp dữ liệu/traveloka/ha_noi.json'
path_hcm = '/content/drive/MyDrive/HUST/20202/Tích hợp dữ liệu/traveloka/ho_chi_minh.json'
path_danang = '/content/drive/MyDrive/HUST/20202/Tích hợp dữ liệu/traveloka/da_nang.json'

import pandas as pd

# %%
hanoi = pd.read_json(path_hanoi)
hcm = pd.read_json(path_hcm)
danang = pd.read_json(path_danang)
hanoi.T
# Out:
#                                                                         0   ...                                                 94
# day_crawl_check_in                                              10/07/2021  ...                                         10/07/2021
# url                      https://www.traveloka.com/vi-vn/hotel/vietnam/...  ...  https://www.traveloka.com/vi-vn/hotel/vietnam/...
# name                     Khách Sạn The Oriental Jade\n(The Oriental Jad...  ...  Khách sạn Lenid De Hồ Gươm\n(Lenid De Ho Guom ...
# address                  92 - 94 Hàng Trống, Phường Hàng Trống, Quận ...  ...  38 Hai Bà Trưng, Tràng Tiền, Quận Hoàn Kiếm, ...
# price                                                        1.120.324 VND  ...                                        812.000 VND
# star                                                                     5  ...                                                  3
# ...

# %%
path_hanoi = '/content/drive/MyDrive/HUST/20202/Tích hợp dữ liệu/data/' + 'ha_noi.csv'
path_hcm = '/content/drive/MyDrive/HUST/20202/Tích hợp dữ liệu/data/' + 'ho_chi_minh.csv'
path_danang = '/content/drive/MyDrive/HUST/20202/Tích hợp dữ liệu/data/' + 'da_nang.csv'

hanoi.to_csv(path_hanoi, index=False)
hcm.to_csv(path_hcm, index=False)
danang.to_csv(path_danang, index=False)
print('Done!')
# Out:
# Done!
